# %%
pip install langchain-google-genai
# Out:
# ...
#   Using cached google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# ...
# Using cached google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# Set key as environment variable
os.environ["GOOGLE_API_KEY"] = "AIzaSyCNq80q_DtvlwpevC3ViaN60uPuxou8O5M"

llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")
response = llm.invoke("Write me a joke about engineers.")
print(response.content)
# Out:
# Why was the engineer sad?  Because they didn't get the *arctan* of their problems.

# %%
pip install langchain-google-genai faiss-cpu langchain pypdf
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: langchain-google-genai in c:\users\masaj\anaconda3\lib\site-packages (2.1.10)
# ...
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/18.2 MB 5.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.1/18.2 MB 5.9 MB/s eta 0:00:03
#    -------- ------------------------------- 3.7/18.2 MB 6.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.7/18.2 MB 6.1 MB/s eta 0:00:03
#    ------------ --------------------------- 5.8/18.2 MB 5.9 MB/s eta 0:00:03
#    --------------- ------------------------ 6.8/18.2 MB 5.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.1/18.2 MB 5.7 MB/s eta 0:00:02
#    -------------------- ------------------- 9.2/18.2 MB 5.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 10.5/18.2 MB 5.6 MB/s eta 0:00:02
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro", google_api_key="AIzaSyCNq80q_DtvlwpevC3ViaN60uPuxou8O5M")

# %%
pip install -U langchain-community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 5.4 MB/s  0:00:00
# ...
#
#   Attempting uninstall: typing-extensions
#
#     Found existing installation: typing_extensions 4.11.0
#
#     Uninstalling typing_extensions-4.11.0:
#
#    ---------------------------------------- 0/9 [typing-extensions]
#    ---------------------------------------- 0/9 [typing-extensions]
#    ---------------------------------------- 0/9 [typing-extensions]
#    ---------------------------------------- 0/9 [typing-extensions]
#    ---------------------------------------- 0/9 [typing-extensions]
#    ---------------------------------------- 0/9 [typing-extensions]
#    ---------------------------------------- 0/9 [typing-extensions]
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader

# Load your PDF
pdf_path = r"C:\Users\masaj\Downloads\Duyusal_Pazarlama_Sunumu.pdf"   # <-- change this path
loader = PyPDFLoader(pdf_path)
documents = loader.load()

# Chunking (split into smaller pieces)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
docs = text_splitter.split_documents(documents)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI


embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001", google_api_key="AIzaSyCNq80q_DtvlwpevC3ViaN60uPuxou8O5M")

vectorstore = FAISS.from_documents(docs, embeddings)

llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0)

# For embeddings
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
from langchain.chains import RetrievalQA

qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectorstore.as_retriever(),
    chain_type="stuff",
)

query = "What is the main idea of this PDF?"
result = qa.run(query)
print(result)
# Out:
# The main idea of the PDF is to explore the application of sensory marketing in e-commerce to compensate for the lack of physical sensory interaction in online shopping.  It discusses how engaging the senses through digital means can improve the customer experience and build brand loyalty.
